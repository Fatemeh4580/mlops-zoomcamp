# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression, Lasso, Ridge
import matplotlib.pyplot as plt
from sklearn.feature_extraction import DictVectorizer
from scipy.sparse import hstack
import seaborn as sns

# %%
df = pd.read_parquet('../data/yellow_tripdata_2023-01.parquet')
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               2  2023-01-01 00:32:10   2023-01-01 00:40:36              1.0
# 1               2  2023-01-01 00:55:08   2023-01-01 01:01:27              1.0
# 2               2  2023-01-01 00:25:04   2023-01-01 00:37:49              1.0
# 3               1  2023-01-01 00:03:48   2023-01-01 00:13:25              0.0
# 4               2  2023-01-01 00:10:29   2023-01-01 00:21:19              1.0
# ...           ...                  ...                   ...              ...
# 3066761         2  2023-01-31 23:58:34   2023-02-01 00:12:33              NaN
# 3066762         2  2023-01-31 23:31:09   2023-01-31 23:50:36              NaN
# 3066763         2  2023-01-31 23:01:05   2023-01-31 23:25:36              NaN
# 3066764         2  2023-01-31 23:40:00   2023-01-31 23:53:00              NaN
# 3066765         2  2023-01-31 23:07:32   2023-01-31 23:21:56              NaN
#
# ...

# %%
df["duration"] = (df["tpep_dropoff_datetime"] - df['tpep_pickup_datetime']).dt.total_seconds()/60

# %%
df["duration"].std()
# Out:
# 42.594351241920904

# %%
(df["duration"] > 60).mean()
# Out:
# 0.007909961177344473

# %%
df2 = df[(df["duration"] <  60) & (df["duration"] > 1)]
len(df2)/len(df)
# Out:
# 0.9811146334607858

# %%
plt.hist(df2.duration, bins=50)
plt.plot()
# Out:
# []

# %%
df["duration"].describe()
# Out:
# count    3.066766e+06
# mean     1.566900e+01
# std      4.259435e+01
# min     -2.920000e+01
# 25%      7.116667e+00
# 50%      1.151667e+01
# 75%      1.830000e+01
# max      1.002918e+04
# Name: duration, dtype: float64

# %%
df2["duration"].describe()
# Out:
# count    3.008849e+06
# mean     1.420544e+01
# std      9.937594e+00
# min      1.016667e+00
# 25%      7.216667e+00
# 50%      1.155000e+01
# 75%      1.818333e+01
# max      5.998333e+01
# Name: duration, dtype: float64

# %%
print(df2[["DOLocationID", "PULocationID"]].dtypes)
# Out:
# DOLocationID    int64
# PULocationID    int64
# dtype: object

# %%
train_dic = df2[["DOLocationID", "PULocationID"]].astype(str).to_dict(orient="records")
dv = DictVectorizer() ## generates sparse matrix
train = dv.fit_transform(train_dic)

# %%
tr = hstack([train, df2["trip_distance"].values.reshape(-1,1)])
ytr = df2["duration"]

# %%
tr.shape
# Out:
# (3008849, 516)

# %%
lr = LinearRegression()
lr.fit(tr, ytr )
yp = lr.predict(tr)
print(np.mean((yp - ytr)**2)**0.5)
# Out:
# 7.65664491869637

# %%
df3
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2023-02-01 00:32:53   2023-02-01 00:34:34              2.0
# 1               2  2023-02-01 00:35:16   2023-02-01 00:35:30              1.0
# 2               2  2023-02-01 00:35:16   2023-02-01 00:35:30              1.0
# 3               1  2023-02-01 00:29:33   2023-02-01 01:01:38              0.0
# 4               2  2023-02-01 00:12:28   2023-02-01 00:25:46              1.0
# ...           ...                  ...                   ...              ...
# 2913950         2  2023-02-28 23:46:00   2023-03-01 00:05:00              NaN
# 2913951         2  2023-02-28 23:26:02   2023-02-28 23:37:10              NaN
# 2913952         2  2023-02-28 23:24:00   2023-02-28 23:38:00              NaN
# 2913953         2  2023-02-28 23:03:00   2023-02-28 23:10:00              NaN
# 2913954         2  2023-02-28 23:03:03   2023-02-28 23:12:51              NaN
#
# ...

# %%
df3 = pd.read_parquet("../data/yellow_tripdata_2023-02.parquet")
df3["duration"] = (df3["tpep_dropoff_datetime"] - df3["tpep_pickup_datetime"]).dt.total_seconds()/60
ts = hstack([dv.transform(df3[["DOLocationID", "PULocationID"]].astype(str).to_dict(orient="records")),
             df3["trip_distance"].values.reshape(-1,1)])
yts =  df3["duration"]

# %%
lr.score(ts, yts)
# Out:
# 0.025696853826519872

# %%
ypre = lr.predict(ts)

print(np.mean((ypre - yts)**2)**0.5)
# Out:
# 42.28805848201793

# %%
plt.plot(yp, ytr, ".")
plt.show()
